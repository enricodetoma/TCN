# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# python pmnist_test.py --ksize 8 --nhid 20 --ksize 6 --acc-file 8x20_test_acc.txt --epoch 10
# python pmnist_test.py --ksize 8 --nhid 25 --ksize 7 --acc-file 8x25_test_acc.txt --epoch 10

# %%
fnames = ['8x20_test_acc.txt', '8x25_test_acc.txt', '../../../rnn_sequential_mnist/test_acc_basic_lstm_sequential_mnist_28x28.txt']
labels = ['TCN 8x20, k=6', 'TCN 8x25, k=7', 'LSTM']
plt.clf()

for idx, fname in enumerate(fnames):
    f = open(fname, 'r')
    x = []
    y = []
    for line in f.readlines():
        tmp = line.split(',')
        x.append(int(tmp[0]))
        y.append(float(tmp[1]))
    f.close()
    plt.plot(x, y, label=labels[idx])
plt.xlabel('Iteration', fontsize=15)
plt.ylabel('Testing Accuracy', fontsize=15)
plt.legend(frameon=False, fontsize=12)
